# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # Finance Data Project
#
# In this data project we will focus on exploratory data analysis of stock prices. Keep in mind, this project is just meant to practice your visualization and pandas skills, it is not meant to be a robust financial analysis or be taken as financial advice.
# ____
# ** NOTE: This project is extremely challenging because it will introduce a lot of new concepts and have you looking things up on your own (we'll point you in the right direction) to try to solve the tasks issued. Feel free to just go through the solutions lecture notebook and video as a "walkthrough" project if you don't want to have to look things up yourself. You'll still learn a lot that way! **
# ____
# We'll focus on bank stocks and see how they progressed throughout the [financial crisis](https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%9308) all the way to early 2016.

# %% [markdown]
# ## Get the Data
#
# In this section we will learn how to use pandas to directly read data from Google finance using pandas!
#
# First we need to start with the proper imports, which we've already laid out for you here.
#
# *Note: [You'll need to install pandas-datareader for this to work!](https://github.com/pydata/pandas-datareader) Pandas datareader allows you to [read stock information directly from the internet](http://pandas.pydata.org/pandas-docs/stable/remote_data.html) Use these links for install guidance (**pip install pandas-datareader**), or just follow along with the video lecture.*
#
# ### The Imports
#
# Already filled out for you.

# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
# %matplotlib inline

# %% [markdown]
# ## Data
#
# We need to get data using pandas datareader. We will get stock information for the following banks:
# *  Bank of America
# * CitiGroup
# * Goldman Sachs
# * JPMorgan Chase
# * Morgan Stanley
# * Wells Fargo
#
# ** Figure out how to get the stock data from Jan 1st 2006 to Jan 1st 2016 for each of these banks. Set each bank to be a separate dataframe, with the variable name for that bank being its ticker symbol. This will involve a few steps:**
# 1. Use datetime to set start and end datetime objects.
# 2. Figure out the ticker symbol for each bank.
# 2. Figure out how to use datareader to grab info on the stock.
#
# ** Use [this documentation page](http://pandas.pydata.org/pandas-docs/stable/remote_data.html) for hints and instructions (it should just be a matter of replacing certain values. Use google finance as a source, for example:**
#
#     # Bank of America
#     BAC = data.DataReader("BAC", 'google', start, end)

# %%
#Use datetime to set start and end datetime objects
start = datetime.datetime.strptime('01-Jan-2006','%d-%b-%Y')
end = datetime.datetime.strptime('01-Jan-2016','%d-%b-%Y')

# %%
#Figure out the ticker symbol for each bank.
#First we can try to get the list of all the stock symbols as follows
symbols = data.get_nasdaq_symbols()

# %%
#try and get the ticker symbol of Bank of America common stock
symbols[symbols['Security Name'].apply(lambda x: x[0:len('Bank of America')] == 'Bank of America')].head(2)
#Which is found to be BAC from below
# Out:
#         Nasdaq Traded                                      Security Name  \
# Symbol
# BAC              True           Bank of America Corporation Common Stock
# BAC$A            True  Bank of America Corporation Depositary Shares,...
#
#        Listing Exchange Market Category    ETF  Round Lot Size  Test Issue  \
# Symbol
# BAC                   N                  False           100.0       False
# BAC$A                 N                  False           100.0       False
#
#        Financial Status CQS Symbol NASDAQ Symbol  NextShares
# Symbol
# BAC                 NaN        BAC           BAC       False
# BAC$A               NaN      BACpA         BAC-A       False

# %%
#try and get the ticker symbol of Citigroup common stock
symbols[symbols['Security Name'].apply(lambda x: x[0:len('Citi')] == 'Citi')].head(2)
#Which is found to be C from below
# Out:
#         Nasdaq Traded                                      Security Name  \
# Symbol
# C                True                       Citigroup, Inc. Common Stock
# C$J              True  Citigroup Inc. Dep Shs Repstg 1/1000 Pfd Ser J...
#
#        Listing Exchange Market Category    ETF  Round Lot Size  Test Issue  \
# Symbol
# C                     N                  False           100.0       False
# C$J                   N                  False           100.0       False
#
#        Financial Status CQS Symbol NASDAQ Symbol  NextShares
# Symbol
# C                   NaN          C             C       False
# C$J                 NaN        CpJ           C-J       False

# %%
#try and get the ticker symbol of Goldman Sachs common stock
symbols[symbols['Security Name'].apply(lambda x: x[0:len('Goldman')] == 'Goldman')].head(100)
#Which is found to be GS from below
# Out:
#         Nasdaq Traded                                      Security Name  \
# Symbol
# GBIL             True         Goldman Sachs Access Treasury 0-1 Year ETF
# GBUY             True           Goldman Sachs Motif New Age Consumer ETF
# GDAT             True          Goldman Sachs Motif Data-Driven World ETF
# GDNA             True            Goldman Sachs Motif Human Evolution ETF
# GEM              True  Goldman Sachs ActiveBeta Emerging Markets Equi...
# GER              True          Goldman Sachs MLP Energy Renaissance Fund
# GFIN             True         Goldman Sachs Motif Finance Reimagined ETF
# GHYB             True  Goldman Sachs Access High Yield Corporate Bond...
# GIGB             True  Goldman Sachs Access Investment Grade Corporat...
# GJS              True  Goldman Sachs Group Securities STRATS Trust fo...
# GMAN             True   Goldman Sachs Motif Manufacturing Revolution ETF
# GMZ              True        Goldman Sachs MLP Income Opportunities Fund
# ...

# %%
#try and get the ticker symbol of JPMorgan Chase common stock
symbols[symbols['Security Name'].apply(lambda x: x[0:len('JP')] == 'JP')].head(100)
#Which is found to be JPM from below
# Out:
#         Nasdaq Traded                                      Security Name  \
# Symbol
# AMJ              True  JPMorgan Chase Capital XVI JP Morgan Alerian M...
# BBAX             True  JPMorgan BetaBuilders Developed Asia-ex Japan ...
# BBCA             True                  JPMorgan BetaBuilders Canada ETF
# BBEU             True                  JPMorgan BetaBuilders Europe ETF
# BBJP             True                   JPMorgan BetaBuilders Japan ETF
# BBRE             True          JPMorgan BetaBuilders MSCI U.S. REIT ETF
# BBSA             True  JPMorgan BetaBuilders 1-5 Year U.S. Aggregate ...
# BBUS             True              JPMorgan BetaBuilders U.S. Equity ETF
# JAGG             True                   JPMorgan U.S. Aggregate Bond ETF
# JCPB             True                        JPMorgan Core Plus Bond ETF
# JDIV             True                         JPMorgan U.S. Dividend ETF
# JIGB             True      JPMorgan Corporate Bond Research Enhanced ETF
# ...

# %%
#try and get the ticker symbol of Morgan Stanley common stock
symbols[symbols['Security Name'].apply(lambda x: x[0:len('Morgan')] == 'Morgan')].head()
#Which is found to be MS from below
# Out:
#         Nasdaq Traded                                      Security Name  \
# Symbol
# CAF              True  Morgan Stanley China A Share Fund Inc. Common ...
# EDD              True  Morgan Stanley Emerging Markets Domestic Debt ...
# IIF              True  Morgan Stanley India Investment Fund, Inc. Com...
# MLPY             True   Morgan Stanley Cushing MLP High Income Index ETN
# MS               True                        Morgan Stanley Common Stock
#
#        Listing Exchange Market Category    ETF  Round Lot Size  Test Issue  \
# Symbol
# CAF                   N                  False           100.0       False
# EDD                   N                  False           100.0       False
# IIF                   N                  False           100.0       False
# MLPY                  P                  False           100.0       False
# MS                    N                  False           100.0       False
#
# ...

# %%
#try and get the ticker symbol of Wells Fargo common stock
symbols[symbols['Security Name'].apply(lambda x: x[0:len('Wells Fargo')] == 'Wells Fargo')].head()
#Which is found to be WFC from below
# Out:
#         Nasdaq Traded                                      Security Name  \
# Symbol
# EAD              True  Wells Fargo Income Opportunities Fund Common S...
# EOD              True       Wells Fargo Global Dividend Opportunity Fund
# ERC              True  Wells Fargo Multi-Sector Income Fund Common St...
# ERH              True         Wells Fargo Utilities and High Income Fund
# WFC              True                 Wells Fargo & Company Common Stock
#
#        Listing Exchange Market Category    ETF  Round Lot Size  Test Issue  \
# Symbol
# EAD                   A                  False           100.0       False
# EOD                   N                  False           100.0       False
# ERC                   A                  False           100.0       False
# ERH                   A                  False           100.0       False
# WFC                   N                  False           100.0       False
#
# ...

# %%
#Figure out how to use datareader to grab info on the stock.
BAC=data.DataReader("BAC",'yahoo',start,end)
C = data.DataReader("C",'yahoo',start,end)
GS = data.DataReader("GS",'yahoo',start,end)
JPM = data.DataReader("JPM",'yahoo',start,end)
MS = data.DataReader("MS",'yahoo',start,end)
WFC = data.DataReader("WFC",'yahoo',start,end)

# %% [markdown]
# ** Create a list of the ticker symbols (as strings) in alphabetical order. Call this list: tickers**

# %%
tickers=[]
stock_name = ['Bank of America Corporation Common Stock', 'Citigroup, Inc. Common Stock', 'Goldman Sachs Group, Inc. (The) Common Stock', 'JP Morgan Chase & Co. Common Stock', 'Morgan Stanley Common Stock', 'Wells Fargo & Company Common Stock']
for i in stock_name:
    tickers.append(symbols[symbols['Security Name'].apply(lambda x: x[0:len(i)] == i)].head(1)['NASDAQ Symbol'].values[0])
tickers.sort()
tickers
# Out:
# ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %% [markdown]
# ** Use pd.concat to concatenate the bank dataframes together to a single data frame called bank_stocks. Set the keys argument equal to the tickers list. Also pay attention to what axis you concatenate on.**

# %%
bank_data = pd.concat([BAC,C,GS,JPM,MS,WFC],keys=tickers,axis=1)
bank_data.head()
# Out:
#                   BAC                                                          \
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  35.717861
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  35.338535
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  35.384048
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  35.330940
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  35.353695
#
#                      C                                      ...         MS  \
#                   High         Low        Open       Close  ...       Open
# Date                                                        ...
# 2006-01-03  493.799988  481.100006  490.000000  492.899994  ...  57.169998
# 2006-01-04  491.000000  483.500000  488.600006  483.799988  ...  58.700001
# ...

# %% [markdown]
# ** Set the column name levels (this is filled out for you):**

# %%
bank_data.columns.names = ['Bank Ticker','Stock Info']

# %% [markdown]
# ** Check the head of the bank_stocks dataframe.**

# %%
bank_data.head()
# Out:
# Bank Ticker        BAC                                               \
# Stock Info        High        Low       Open      Close      Volume
# Date
# 2006-01-03   47.180000  46.150002  46.919998  47.080002  16296700.0
# 2006-01-04   47.240002  46.450001  47.000000  46.580002  17757900.0
# 2006-01-05   46.830002  46.320000  46.580002  46.639999  14970700.0
# 2006-01-06   46.910000  46.349998  46.799999  46.570000  12599800.0
# 2006-01-09   46.970001  46.360001  46.720001  46.599998  15619400.0
#
# Bank Ticker                      C                                      ...  \
# Stock Info   Adj Close        High         Low        Open       Close  ...
# Date                                                                    ...
# 2006-01-03   35.717861  493.799988  481.100006  490.000000  492.899994  ...
# 2006-01-04   35.338535  491.000000  483.500000  488.600006  483.799988  ...
# 2006-01-05   35.384048  487.799988  484.000000  484.399994  486.200012  ...
# ...

# %% [markdown]
# # EDA
#
# Let's explore the data a bit! Before continuing, I encourage you to check out the documentation on [Multi-Level Indexing](http://pandas.pydata.org/pandas-docs/stable/advanced.html) and [Using .xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html).
# Reference the solutions if you can not figure out how to use .xs(), since that will be a major part of this project.
#
# ** What is the max Close price for each bank's stock throughout the time period?**

# %%
bank_data.xs('Close',level=1,axis=1).max()
# Out:
# Bank Ticker
# BAC     54.900002
# C      564.099976
# GS     247.919998
# JPM     70.080002
# MS      89.300003
# WFC     58.520000
# dtype: float64

# %% [markdown]
# ** Create a new empty DataFrame called returns. This dataframe will contain the returns for each bank's stock. returns are typically defined by:**
#
# $$r_t = \frac{p_t - p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1$$

# %%
returns = pd.DataFrame()

# %% [markdown]
# ** We can use pandas pct_change() method on the Close column to create a column representing this return value. Create a for loop that goes and for each Bank Stock Ticker creates this returns column and set's it as a column in the returns DataFrame.**

# %%
for i in tickers:
    returns[i+"-Returns"] = bank_data.xs('Close',level=1,axis=1)[i].pct_change()
returns.head()
# Out:
#             BAC-Returns  C-Returns  GS-Returns  JPM-Returns  MS-Returns  \
# Date
# 2006-01-03          NaN        NaN         NaN          NaN         NaN
# 2006-01-04    -0.010620  -0.018462   -0.013812    -0.014183    0.000686
# 2006-01-05     0.001288   0.004961   -0.000393     0.003029    0.002742
# 2006-01-06    -0.001501   0.000000    0.014169     0.007046    0.001025
# 2006-01-09     0.000644  -0.004731    0.012030     0.016242    0.010586
#
#             WFC-Returns
# Date
# 2006-01-03          NaN
# 2006-01-04    -0.011599
# 2006-01-05    -0.001110
# 2006-01-06     0.005874
# 2006-01-09    -0.000158

# %% [markdown]
# ** Create a pairplot using seaborn of the returns dataframe. What stock stands out to you? Can you figure out why?**

# %%
import seaborn as sns
sns.pairplot(returns[1:])
#The Citi Group Stock stands out as it gives the maximum returns.

# %% [markdown]
# * See solution for details about Citigroup behavior....

# %% [markdown]
# ** Using this returns DataFrame, figure out on what dates each bank stock had the best and worst single day returns. You should notice that 4 of the banks share the same day for the worst drop, did anything significant happen that day?**

# %%
# Method -1
banks=[]
best=[]
worst=[]
for i in returns.columns:
    banks.append(i)
    best.append(str(returns[returns[i] == returns[i].max()][i].index[0])[0:11])
    worst.append(str(returns[returns[i] == returns[i].min()][i].index[0])[0:11])
best_worst = pd.DataFrame()
best_worst['Bank'] = banks
best_worst['Best Day'] = best
best_worst['Worst Day'] = worst
best_worst
# Out:
#           Bank     Best Day    Worst Day
# 0  BAC-Returns  2009-04-09   2009-01-20
# 1    C-Returns  2008-11-24   2009-02-27
# 2   GS-Returns  2008-11-24   2009-01-20
# 3  JPM-Returns  2009-01-21   2009-01-20
# 4   MS-Returns  2008-10-13   2008-10-09
# 5  WFC-Returns  2008-07-16   2009-01-20

# %%
# Method 2
returns.idxmax() #returns the best day (index) for each stock
# Out:
# BAC-Returns   2009-04-09
# C-Returns     2008-11-24
# GS-Returns    2008-11-24
# JPM-Returns   2009-01-21
# MS-Returns    2008-10-13
# WFC-Returns   2008-07-16
# dtype: datetime64[ns]

# %%
returns.idxmin() #returns the worst day (index) for each stock
# Out:
# BAC-Returns   2009-01-20
# C-Returns     2009-02-27
# GS-Returns    2009-01-20
# JPM-Returns   2009-01-20
# MS-Returns    2008-10-09
# WFC-Returns   2009-01-20
# dtype: datetime64[ns]

# %% [markdown]
# ** You should have noticed that Citigroup's largest drop and biggest gain were very close to one another, did anythign significant happen in that time frame? **

# %% [markdown]
# * See Solution for details

# %% [markdown]
# Nothing specifically noticable in Citigroup (C-Returns), however JP Morgan (JPM-Returns) is clearly showing a gain & loss
# within 2 days. JP Morgan had a stock splitting in 2009.

# %% [markdown]
# ** Take a look at the standard deviation of the returns, which stock would you classify as the riskiest over the entire time period? Which would you classify as the riskiest for the year 2015?**

# %%
returns.std()
# Out:
# BAC-Returns    0.036647
# C-Returns      0.038672
# GS-Returns     0.025390
# JPM-Returns    0.027667
# MS-Returns     0.037819
# WFC-Returns    0.030238
# dtype: float64

# %% [markdown]
# The riskiest stock would be Citigroup's considering the standard deviation stats.

# %%
returns.loc['2015-01-01':'2015-12-01'].std()
# Out:
# BAC-Returns    0.015959
# C-Returns      0.015102
# GS-Returns     0.013468
# JPM-Returns    0.013775
# MS-Returns     0.015841
# WFC-Returns    0.012354
# dtype: float64

# %% [markdown]
# Stocks of 'Bank of America' and 'Mogan Stanley' appear to be the riskiest in 2015

# %% [markdown]
# ** Create a distplot using seaborn of the 2015 returns for Morgan Stanley **

# %%
sns.distplot(returns.loc['2015-01-01':'2015-12-31']['MS-Returns'],bins=50)

# %% [markdown]
# ** Create a distplot using seaborn of the 2008 returns for CitiGroup **

# %%
sns.distplot(returns.loc['2008-01-01':'2008-12-31']['C-Returns'],bins=50,color='green')

# %% [markdown]
# ____
# # More Visualization
#
# A lot of this project will focus on visualizations. Feel free to use any of your preferred visualization libraries to try to recreate the described plots below, seaborn, matplotlib, plotly and cufflinks, or just pandas.
#
# ### Imports

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# Optional Plotly Method Imports
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ** Create a line plot showing Close price for each bank for the entire index of time. (Hint: Try using a for loop, or use [.xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html) to get a cross section of the data.)**

# %%
bank_data.xs('Close',level=1,axis=1).plot(kind='line',figsize=(15,6))

# %% [markdown]
# ## Moving Averages
#
# Let's analyze the moving averages for these stocks in the year 2008.
#
# ** Plot the rolling 30 day average against the Close Price for Bank Of America's stock for the year 2008**

# %%
bank_data['BAC']['Close'].loc['2008-01-01':'2009-01-01'].plot(kind='line')

# %% [markdown]
# ** Create a heatmap of the correlation between the stocks Close Price.**

# %%
sns.heatmap(bank_data.xs('Close',level=1,axis=1).corr(),annot=True,cmap='Greens')

# %% [markdown]
# ** Optional: Use seaborn's clustermap to cluster the correlations together:**

# %%
sns.clustermap(bank_data.xs('Close',level=1,axis=1).corr(),annot=True,cmap='Greens')

# %% [markdown]
# # Part 2 (Optional)
#
# In this second part of the project we will rely on the cufflinks library to create some Technical Analysis plots. This part of the project is experimental due to its heavy reliance on the cuffinks project, so feel free to skip it if any functionality is broken in the future.

# %% [markdown]
# ** Use .iplot(kind='candle) to create a candle plot of Bank of America's stock from Jan 1st 2015 to Jan 1st 2016.**

# %%
bank_data['BAC'].loc['2015-01-01':'2016-01-01'].iplot(kind='candle')
# Out:
# <div>
#
#
#             <div id="e9ee5502-3856-4abe-976e-450e245a9d61" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e9ee5502-3856-4abe-976e-450e245a9d61")) {
#                     Plotly.newPlot(
#                         'e9ee5502-3856-4abe-976e-450e245a9d61',
# ...

# %% [markdown]
# ** Use .ta_plot(study='sma') to create a Simple Moving Averages plot of Morgan Stanley for the year 2015.**

# %%
bank_data['MS'].loc['2015-01-01':'2016-01-01'].ta_plot(study='sma')
# Out:
# <div>
#
#
#             <div id="b1b155f7-ea2c-4c5c-8194-e6ea598a7b72" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b1b155f7-ea2c-4c5c-8194-e6ea598a7b72")) {
#                     Plotly.newPlot(
#                         'b1b155f7-ea2c-4c5c-8194-e6ea598a7b72',
# ...

# %% [markdown]
# **Use .ta_plot(study='boll') to create a Bollinger Band Plot for Bank of America for the year 2015.**

# %%
bank_data['BAC'].loc['2015-01-01':'2016-01-01'].ta_plot(study='boll')
# Out:
# <div>
#
#
#             <div id="01819b24-2db3-40c1-979c-d8fe13c39ae6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("01819b24-2db3-40c1-979c-d8fe13c39ae6")) {
#                     Plotly.newPlot(
#                         '01819b24-2db3-40c1-979c-d8fe13c39ae6',
# ...
